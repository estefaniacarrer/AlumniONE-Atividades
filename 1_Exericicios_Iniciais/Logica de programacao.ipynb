# %% [markdown]
# # Lógica de programação com Python

# %%
1+1
# Out:
# 2

# %%
"Estefania"
# Out:
# 'Estefania'

# %%
'Estefania'
# Out:
# 'Estefania'

# %%
nome = 'Estefania'

# %%
nome
# Out:
# 'Estefania'

# %%
idade = 30

# %%
idade
# Out:
# 30

# %%
print(f'O nome é {nome} e sua idade é {idade} anos')
# Out:
# O nome é Estefania e sua idade é 30 anos

# %%
idade = 31

# %%
print(f'O nome é {nome} e sua idade é {idade} anos')
# Out:
# O nome é Estefania e sua idade é 31 anos

# %% [markdown]
# # Criando minha primeira função

# %%
def saudacao():
  nome = input('Qual o seu nome? ')
  print(f'Olá {nome}')

# %%
saudacao()
# Out:
# Qual o seu nome? Estefania
# Olá Estefania

# %% [markdown]
# # Parametros

# %%
nome = 'Luiza'

# %%
def saudacao_com_parametros(nome_da_pessoa):
  print(f'Olá {nome_da_pessoa}')

# %%
saudacao_com_parametros(nome)
# Out:
# Olá Luiza

# %% [markdown]
# # Condicional

# %%
idade = 15

def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print('Tem permissão para dirigir')
  else:
    print('Não tem permissão para dirigir')

verifica_se_pode_dirigir(idade)
# Out:
# Não tem permissão para dirigir

# %% [markdown]
# # Convertendo tipo para inteiro

# %%
def verifica_se_pode_dirigir_sem_parametros():
  idade = input('Qual a sua idade? ')
  idade = int(idade)

  if idade >= 18:
    print('Tem permissao para dirigir')
  else:
    print('Não tem permissão para dirigir')

verifica_se_pode_dirigir_sem_parametros()
# Out:
# Qual a sua idade? 15
# Não tem permissão para dirigir

# %% [markdown]
# # Lista

# %%
idade = 22
idade
# Out:
# 22

# %%
type(idade)
# Out:
# int

# %%
nome: 'Estefania'
type(nome)
# Out:
# str

# %%
idades = [18, 22, 15, 50]
type(idades)
# Out:
# list

# %%
idades[2]
# Out:
# 15

# %%
idades = [18, 22, 15, 50]
#          0   1   2   3
#          0  -3  -2  -1

# %%
idades[1]
# Out:
# 22

# %%
idades[0:3]
# Out:
# [18, 22, 15]

# %%
idades[1:]
# Out:
# [22, 15, 50]

# %%
idades[-1]
# Out:
# 50

# %%
idades[-2]
# Out:
# 15

# %% [markdown]
# # Laços e Loops

# %%
idades
# Out:
# [18, 22, 15, 50]

# %%
#for fora da função

def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print(f'{idade} anos de idade, Tem permissão para dirigir')
  else:
    print(f'{idade} anos de idade, Não tem permissão para dirigir')

for idade in idades:
  verifica_se_pode_dirigir(idade)
# Out:
# 18 anos de idade, Tem permissão para dirigir
# 22 anos de idade, Tem permissão para dirigir
# 15 anos de idade, Não tem permissão para dirigir
# 50 anos de idade, Tem permissão para dirigir

# %%
def verifica_se_pode_dirigir(idade):
  for idade in idades:
    if idade >= 18:
      print(f'{idade} anos de idade, Tem permissão para dirigir')
    else:
      print(f'{idade} anos de idade, Não tem permissão para dirigir')

verifica_se_pode_dirigir(idades)
# Out:
# 18 anos de idade, Tem permissão para dirigir
# 22 anos de idade, Tem permissão para dirigir
# 15 anos de idade, Não tem permissão para dirigir
# 50 anos de idade, Tem permissão para dirigir

# %% [markdown]
# # Booleano

# %%
idade = 18
idade >= 18
# Out:
# True

# %%
idade = 15
idade >= 18
# Out:
# False

# %%
permissoes = []
idades = [20, 14, 40]

def verifica_se_pode_dirigir(idades, permissoes):
  for idade in idades:
    if idade >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False)

verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print('Tem permissao para dirigir')
  else:
    print('Não tem permissao para dirigir')
# Out:
# Tem permissao para dirigir
# Não tem permissao para dirigir
# Tem permissao para dirigir

# %% [markdown]
# # Tipos de uma lista

# %%
lista = ['Estefania', 30, True, '18']

for elemento in lista:
  print(f'O elemento {elemento} é do tipo: ', type(elemento))
# Out:
# O elemento Estefania é do tipo:  <class 'str'>
# O elemento 30 é do tipo:  <class 'int'>
# O elemento True é do tipo:  <class 'bool'>
# O elemento 18 é do tipo:  <class 'str'>

# %% [markdown]
# # Imports

# %%
from random import randrange, seed

# %%
seed(15)

# %%
randrange(0,11)
# Out:
# 3

# %%
notas_matematica = []

for notas in range(8):
  notas_matematica.append(randrange(0,11))

notas_matematica
# Out:
# [10, 2, 5, 3, 1, 5, 7, 5]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# # Grafico - Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))
y = notas_matematica
plt.plot(x, y, marker='o')
plt.title('Notas de matematica')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()

# %%
notas_matematica
# Out:
# [10, 2, 5, 3, 1, 5, 7, 5]
